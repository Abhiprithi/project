# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Df=pd.read_csv("DOC-20230208-WA0001..csv")

# %%
Df.head ()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51165 entries, 0 to 51164
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    51165 non-null  object
#  1   StockCode    51165 non-null  object
#  2   Description  51020 non-null  object
#  3   Quantity     51165 non-null  int64
#  4   InvoiceDate  51164 non-null  object
#  5   UnitPrice    51164 non-null  float64
#  6   CustomerID   32760 non-null  float64
#  7   Country      51164 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 3.1+ MB

# %%
Df.describe()
# Out:
#            Quantity     UnitPrice    CustomerID
# count  51165.000000  51164.000000  32760.000000
# mean       8.193433      6.357762  15411.000549
# std       56.291553    164.619461   1759.759629
# min    -9360.000000      0.000000  12347.000000
# 25%        1.000000      1.250000  14032.000000
# 50%        2.000000      2.510000  15456.000000
# 75%        8.000000      4.250000  17019.000000
# max     2880.000000  16888.020000  18283.000000

# %%
Df['Quantity'].value_counts()
# Out:
#  1      17069
#  2       7931
#  12      4457
#  3       3670
#  6       3562
#         ...
#  55         1
#  66         1
#  258        1
#  67         1
# -990        1
# Name: Quantity, Length: 218, dtype: int64

# %%
Df['CustomerID'].value_counts()
# Out:
# 12748.0    684
# 17841.0    393
# 14911.0    346
# 14606.0    333
# 17850.0    297
#           ...
# 14850.0      1
# 17616.0      1
# 17720.0      1
# 15179.0      1
# 18193.0      1
# Name: CustomerID, Length: 1057, dtype: int64

# %%
Df['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    291
# REGENCY CAKESTAND 3 TIER              231
# HAND WARMER BABUSHKA DESIGN           192
# PAPER CHAIN KIT 50'S CHRISTMAS        180
# HEART OF WICKER SMALL                 179
#                                      ...
# FLOWER PURPLE CLOCK W/SUCKER            1
# CANDY SPOT HEART DECORATION             1
# BLUE KNITTED HEN                        1
# LARGE TORTILLA DESIGN RED BOWL          1
# PINK CHERRY LIGHTS                      1
# Name: Description, Length: 2824, dtype: int64

# %%
sns.countplot(data=Df,x='CustomerID')

# %%
sns.countplot(data=Df,x='Quantity')

# %%
Df['UnitPrice'].value_counts()
# Out:
# 1.25      4171
# 0.85      4050
# 2.95      3074
# 1.65      2602
# 2.51      2444
#           ...
# 729.42       1
# 267.12       1
# 145.00       1
# 19.94        1
# 6.70         1
# Name: UnitPrice, Length: 316, dtype: int64

# %%
sns.countplot(data=Df,x='UnitPrice')

# %%
p_class =Df[['Quantity', 'UnitPrice']]
p_class.head()
# Out:
#    Quantity  UnitPrice
# 0         6       2.55
# 1         6       3.39
# 2         8       2.75
# 3         6       3.39
# 4         6       3.39

# %%
sns.countplot  (  data=Df  ,  x=  'InvoiceNo' )

# %%
sns.countplot(data=Df,x='Country')

# %%
sns.countplot(data=Df,x='UnitPrice')

# %%
Df.isnull().sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description      145
# Quantity           0
# InvoiceDate        1
# UnitPrice          1
# CustomerID     18405
# Country            1
# dtype: int64

# %%
sns.heatmap(Df.isnull(), yticklabels=False, cbar=False)

# %%
Df.Quantity.value_counts().plot(kind='pie')

# %%
Df.CustomerID.value_counts().plot(kind='pie')

# %%
Df.UnitPrice.value_counts().plot(kind='pie')

# %%
Df.InvoiceNo.value_counts().plot(kind='pie')

# %%
Df.StockCode.value_counts().plot(kind='pie')

# %%
Df.Description.value_counts().plot(kind='pie')

# %%
Df.Quantity.value_counts().plot(kind='pie')

# %%
Df.CustomerID.value_counts().plot(kind='pie')

# %%
Df.Quantity.plot(kind='hist',bins=30,color='black')

# %%
map_dict = {
    'First':1,
    'Second': 2,
    'Third': 3
}

# %%
Df['Quantity'].unique()
# Out:
# array([    6,     8,     2,    32,     3,     4,    24,    12,    48,
#           18,    20,    36,    80,    64,    10,   120,    96,    23,
#            5,     1,    -1,    50,    40,   100,   192,   432,   144,
#          288,   -12,   -24,    16,     9,   128,    25,    30,    28,
#            7,    56,    72,   200,   600,   480,    -6,    14,    -2,
#           11,    33,    13,    -4,    -5,    -7,    -3,    70,   252,
#           60,   216,   384,   -10,    27,    15,    22,    19,    17,
#           21,    34,    47,   108,    52, -9360,   -38,    75,   270,
#           42,   240,    90,   320,  1824,   204,    69,   -36,  -192,
#         -144,   160,  2880,  1400,    39,   -48,   -50,    26,  1440,
#           31,    82,    78,    97,    98,    35,    57,   -20,   110,
#          -22,   -30,   -70,  -130,   -80,  -120,   -40,   -25,   -14,
#          -15,   -69,  -140,  -320,    -8,   720,   156,   324,    38,
# ...

# %%
correlation = Df.corr()
correlation
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.003815   -0.026889
# UnitPrice  -0.003815   1.000000   -0.009624
# CustomerID -0.026889  -0.009624    1.000000
