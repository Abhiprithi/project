# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
housing=pd.read_csv("dataset.csv")

# %%
housing.head()
# Out:
#    Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           0    -122.23     37.88                41.0        880.0
# 1           1    -122.22     37.86                21.0       7099.0
# 2           2    -122.24     37.85                52.0       1467.0
# 3           3    -122.25     37.85                52.0       1274.0
# 4           4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# ...

# %%
housing.isnull().sum()
# Out:
# Unnamed: 0              0
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
housing['total_bedrooms'].plot(kind='hist')
plt.xlabel('Total bedrooms')
# Out:
# Text(0.5, 0, 'Total bedrooms')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          20640 non-null  int64
#  1   longitude           20640 non-null  float64
#  2   latitude            20640 non-null  float64
#  3   housing_median_age  20640 non-null  float64
#  4   total_rooms         20640 non-null  float64
#  5   total_bedrooms      20433 non-null  float64
#  6   population          20640 non-null  float64
#  7   households          20640 non-null  float64
#  8   median_income       20640 non-null  float64
#  9   median_house_value  20640 non-null  float64
#  10  ocean_proximity     20640 non-null  object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
housing_df=housing.copy()

# %%
housin_null_dropped=housing.dropna()

# %%
housin_null_dropped.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
housin_null_dropped_2=housing_df.dropna(axis='columns')

# %%
housin_null_dropped_2.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          20640 non-null  int64
#  1   longitude           20640 non-null  float64
#  2   latitude            20640 non-null  float64
#  3   housing_median_age  20640 non-null  float64
#  4   total_rooms         20640 non-null  float64
#  5   total_bedrooms      20433 non-null  float64
#  6   population          20640 non-null  float64
#  7   households          20640 non-null  float64
#  8   median_income       20640 non-null  float64
#  9   median_house_value  20640 non-null  float64
#  10  ocean_proximity     20640 non-null  object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
housing_filled=housing.fillna(3)

# %%
housing_filled.isnull().sum()
# Out:
# Unnamed: 0            0
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
housing_filled=housing_df.fillna(method='bfill')

# %%
type(housing)
# Out:
# pandas.core.frame.DataFrame

# %%
housing.describe()
# Out:
#          Unnamed: 0     longitude      latitude  housing_median_age  \
# count  20640.000000  20640.000000  20640.000000        20640.000000
# mean   10319.500000   -119.569704     35.631861           28.639486
# std     5958.399114      2.003532      2.135952           12.585558
# min        0.000000   -124.350000     32.540000            1.000000
# 25%     5159.750000   -121.800000     33.930000           18.000000
# 50%    10319.500000   -118.490000     34.260000           29.000000
# 75%    15479.250000   -118.010000     37.710000           37.000000
# max    20639.000000   -114.310000     41.950000           52.000000
#
#         total_rooms  total_bedrooms    population    households  \
# count  20640.000000    20433.000000  20640.000000  20640.000000
# mean    2635.763081      537.870553   1425.476744    499.539680
# std     2181.615252      421.385070   1132.462122    382.329753
# min        2.000000        1.000000      3.000000      1.000000
# ...

# %%
housing.shape
# Out:
# (20640, 11)

# %%
housing['longitude'].value_counts()
# Out:
# -118.31    162
# -118.30    160
# -118.29    148
# -118.27    144
# -118.32    142
#           ...
# -123.54      1
# -115.94      1
# -115.99      1
# -116.81      1
# -123.71      1
# Name: longitude, Length: 844, dtype: int64

# %%
sns.countplot(data=housing,x='ocean_proximity')

# %%
sns.countplot(data=housing,x='longitude')

# %%
sns.countplot(data=housing,x='latitude')

# %%
sns.countplot(data=housing,x='housing_median_age')

# %%
sns.countplot(data=housing,x='total_rooms')

# %%
sns.countplot(data=housing,x='median_house_value')
